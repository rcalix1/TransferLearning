# %%
import numpy as np

# %%
from fastai.vision.all import *

# %%
path = untar_data(URLs.PETS)/'images'

## this function returns True or False


def is_cat(x):
    return x[0].isupper()


dls = ImageDataLoaders.from_name_func(
               path, 
               get_image_files(path),
               seed=42,
               valid_pct=0.2,
               label_func=is_cat,
               item_tfms=Resize(224)
)

learn = cnn_learner(dls, resnet34, metrics=error_rate )

learn.fine_tune(1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='811712512' class='' max='811706944' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [811712512/811706944 00:13&lt;00:00]
#     </div>
# /home/rcalix/.local/lib/python3.8/site-packages/fastai/vision/learner.py:288: UserWarning: `cnn_learner` has been renamed to `vision_learner` -- please update your code
#   warn("`cnn_learner` has been renamed to `vision_learner` -- please update your code")
# /home/rcalix/.local/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/rcalix/.local/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /home/rcalix/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.179463</td>
#       <td>0.015389</td>
#       <td>0.003383</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.056234</td>
#       <td>0.015044</td>
#       <td>0.005413</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(   path.ls()   )
# Out:
# [Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Birman_199.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/boxer_128.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/basset_hound_164.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Persian_53.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/basset_hound_76.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/german_shorthaired_160.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Siamese_9.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/leonberger_141.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/keeshond_136.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Abyssinian_219.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_118.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/shiba_inu_128.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/japanese_chin_140.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/havanese_168.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Abyssinian_26.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/scottish_terrier_182.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/scottish_terrier_153.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/yorkshire_terrier_16.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/japanese_chin_191.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/great_pyrenees_24.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/pomeranian_102.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/leonberger_190.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/american_pit_bull_terrier_6.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/saint_bernard_107.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/keeshond_16.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Russian_Blue_62.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_139.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/boxer_21.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Birman_148.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Persian_82.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/leonberger_17.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/saint_bernard_41.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_151.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_44.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Russian_Blue_100.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/english_setter_174.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Maine_Coon_78.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/great_pyrenees_173.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Siamese_144.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/newfoundland_37.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Sphynx_30.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Bombay_114.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/newfoundland_134.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Ragdoll_12.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Siamese_195.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_1.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/Bombay_203.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_95.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_35.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/saint_bernard_90.jpg'), Path('/home/rcalix/.fastai/data/oxford-iiit-pet/images/miniature_pinscher_180.j ...

# %%
my_img = '/home/rcalix/.fastai/data/oxford-iiit-pet/images/boxer_21.jpg'

# %%
img = PILImage.create( my_img )

# %%
img
# Out:
# PILImage mode=RGB size=500x333

# %%
is_cat, _, probs = learn.predict(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
print(is_cat)

print(probs)
# Out:
# False
# TensorBase([9.9952e-01, 4.7683e-04])

# %%
second_img = '/home/rcalix/.fastai/data/oxford-iiit-pet/images/Abyssinian_26.jpg'
img = PILImage.create( second_img )

# %%
img
# Out:
# PILImage mode=RGB size=500x369

# %%
is_cat, _, probs = learn.predict(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
print(is_cat)

print(probs)
# Out:
# True
# TensorBase([1.2426e-10, 1.0000e+00])
